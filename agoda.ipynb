# %%
#正式版agoda
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
import time
url="https://www.agoda.com/zh-hk/hotel-midtown-richardson/hotel/taipei-tw.html?finalPriceView=2&isShowMobileAppPrice=false&cid=1844104&numberOfBedrooms=&familyMode=false&adults=2&children=0&rooms=1&maxRooms=0&checkIn=2023-02-23&isCalendarCallout=false&childAges=&numberOfGuest=0&missingChildAges=false&travellerType=1&showReviewSubmissionEntry=false&currencyCode=TWD&isFreeOccSearch=false&isCityHaveAsq=false&tspTypes=2&los=1&searchrequestid=bc2cfce1-3416-42c3-b375-5593c42903ed"
items=[]
options = webdriver.ChromeOptions()
driver=webdriver.Chrome(chrome_options=options,executable_path="chromedriver")
driver.get(url)
count=0
time.sleep(5)
driver.find_element("xpath",'//*[@id="hotelNavBar"]/div/ul/li[4]/button').click()
time.sleep(6)
low=driver.find_element("xpath",'//*[@id="reviewSection"]/div[3]/div[1]/div/div[3]/div/div[1]/div/div/div[5]/div/span/span').click()
while count<=67: #67
    count=count+1
    time.sleep(2)
    all_1=driver.find_element("xpath",'//*[@class="Review-comments"]')
    title=all_1.find_elements("xpath",'//*[@class="Review-comment-bodyTitle"]')
    content=all_1.find_elements("xpath",'//*[@class="Review-comment-bodyText"]')
    for i in range(0,len(title)):
        a=title[i].text.replace('”','').replace('\n','').replace('\r','').replace(',','')
        b=content[i].text.replace('”','').replace('\n','').replace('\r','').replace(',','')
        c=a+b
        items.append(c)
    button=driver.find_elements("xpath",'//*[@id="reviewSection"]/div[4]/div/span[3]/i')
    driver.execute_script("$(arguments[0]).click()",button)
    time.sleep(2)

driver.quit()
print(items)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_15312\3219208981.py:10: DeprecationWarning: use options instead of chrome_options
#   driver=webdriver.Chrome(chrome_options=options,executable_path="chromedriver")
# ...

# %%
print(len(items))
# Out:
# 680

# %%
import csv
with open('comment.csv','w',encoding='utf-8',newline='') as f: #開啟輸出的CSV檔案
    writer=csv.writer(f) #建立CSV檔寫入器
    for item in items:
        writer.writerow((column for column in item))
print('\n讀取 csv 檔')
# Out:
# 讀取 csv 檔

# %%
#正式版agoda
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
import time
url="https://www.agoda.com/zh-tw/vendome-hotel/hotel/taipei-tw.html?finalPriceView=2&isShowMobileAppPrice=false&cid=1844104&numberOfBedrooms=&familyMode=false&adults=2&children=0&rooms=1&maxRooms=0&checkIn=2023-02-17&isCalendarCallout=false&childAges=&numberOfGuest=0&missingChildAges=false&travellerType=1&showReviewSubmissionEntry=false&currencyCode=TWD&isFreeOccSearch=false&isCityHaveAsq=false&los=2&searchrequestid=c34af677-462c-4bdd-801d-a6a5af41db13"
items=[]
options = webdriver.ChromeOptions()
driver=webdriver.Chrome(chrome_options=options,executable_path="chromedriver")
driver.get(url)
count=0
time.sleep(5)
driver.find_element("xpath",'//*[@id="hotelNavBar"]/div/ul/li[3]/button/span').click()
time.sleep(6)
while count<=17: #67
    count=count+1
    time.sleep(2)
    all_1=driver.find_element("xpath",'//*[@class="Review-comments"]')
    title=all_1.find_elements("xpath",'//*[@class="Review-comment-bodyTitle"]')
    content=all_1.find_elements("xpath",'//*[@class="Review-comment-bodyText"]')
    for i in range(0,len(title)):
        a=title[i].text.replace('”','').replace('\n','').replace('\r','').replace(',','')
        b=content[i].text.replace('”','').replace('\n','').replace('\r','').replace(',','')
        c=a+b
        items.append(c)
    button=driver.find_elements("xpath",'//*[@id="reviewSection"]/div[4]/div/span[3]/i')
    driver.execute_script("$(arguments[0]).click()",button)
    time.sleep(2)

driver.quit()
print(items)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_13712\3276167940.py:10: DeprecationWarning: use options instead of chrome_options
#   driver=webdriver.Chrome(chrome_options=options,executable_path="chromedriver")
# ...

# %%
print(len(items))
# Out:
# 360

# %%
import csv
with open('comment.csv','w',encoding='utf-8',newline='') as f: #開啟輸出的CSV檔案
    writer=csv.writer(f) #建立CSV檔寫入器
    for item in items:
        writer.writerow((column for column in item))
print('\n讀取 csv 檔')
# Out:
# 讀取 csv 檔

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.support import expected_conditions
from selenium.webdriver.common.by import By
import time
url="https://www.agoda.com/zh-tw/caesar-metro-taipei/reviews/taipei-tw.html?finalPriceView=1&isShowMobileAppPrice=false&cid=1891473&numberOfBedrooms=&familyMode=false&adults=1&children=0&rooms=1&maxRooms=0&checkIn=2022-10-31&isCalendarCallout=false&childAges=&numberOfGuest=0&missingChildAges=false&travellerType=-1&showReviewSubmissionEntry=false&currencyCode=TWD&isFreeOccSearch=false&tag=8b9aded8-4fb0-d25a-9e18-e0c0d84accae&isCityHaveAsq=false&tspTypes=7%2C5%2C16%2C16%2C-1%2C-1&los=1&searchrequestid=d49d8f12-c27a-47ed-b181-4b89f575e4e6"
items=[]
options = webdriver.ChromeOptions()
driver=webdriver.Chrome(chrome_options=options,executable_path="chromedriver")
#driver.set_page_load_timeout(60)
driver.get(url)
count=0
while count<=5:
    driver.find_element("xpath",'//*[@id="reviewSection"]/div[5]/button').click()
    count=count+1
    time.sleep(1)
all_1=driver.find_element("xpath",'//*[@id="reviewSectionComments"]')
print(all_1.find_element("xpath",'//*[@id="review-249"]/div[2]/div[1]/div[1]/p[1]').text.replace('”',''))
print(all_1.find_element("xpath",'//*[@id="review-249"]/div[2]/div[1]/div[1]/p[2]').text)
driver.quit()
#print(items)
# Out:
# C:\Users\User\AppData\Local\Temp\ipykernel_12592\3047590812.py:10: DeprecationWarning: use options instead of chrome_options
#   driver=webdriver.Chrome(chrome_options=options,executable_path="chromedriver")
# 優質住宿
# 算是一間很新飯店、鄰居車站，價格很實惠，很棒
